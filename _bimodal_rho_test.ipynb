# %%
import torch
import matplotlib.pyplot as plt

from src.diffeomorphisms.vector.star_gaussian import StarGaussianVectorDiffeomorphism
from src.distributions.star_gaussians.r2.cross import CrossStarGaussianDistribution
from src.distributions.star_gaussians.multi_inverse_pre_bias_gaussian import MultiInversePreBiasLinearStarGaussianDistribution
from src.manifolds.euclidean.vector.pullback.standard import StandardPullbackVectorEuclidean

# seed
torch.manual_seed(31)

# %%
# construct star distribution
dist = CrossStarGaussianDistribution()

# %%
# plot density
n_points = 1001
x = torch.linspace(-14, 14, n_points)
y = torch.linspace(-14, 14, n_points)
X, Y = torch.meshgrid(x, y)
XY = torch.stack([X.flatten(), Y.flatten()], dim=-1)
log_probs = torch.exp(dist.log_prob(XY).reshape(n_points, n_points).detach())

plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis')
plt.colorbar(label='Density')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# /Users/wdiepeveen/Documents/Postdoc/projects/6 - Lyme Geometry/Lyme-Geometry/.venv/lib/python3.13/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4383.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# generate samples
samples = dist.sample(2500).detach()

plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
plt.scatter(samples[:,0], samples[:,1], marker='.', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# check normalization integrates to 1 by monte carlo from uniform samples
n_mc_samples = 1000000
mc_samples = (torch.rand(n_mc_samples, 2) - 0.5) * 28.0  # uniform in [-14, 14]^2
mc_log_probs = dist.log_prob(mc_samples)
mc_probs = torch.exp(mc_log_probs)
mc_integral = mc_probs.mean() * (28.0 ** 2)  # area of bounding box
print(f'Monte Carlo integral estimate: {mc_integral.item()}')
# Out:
# Monte Carlo integral estimate: 1.0084303617477417

# %%
# Construct radial vector diffeomorphism
radial_diffeo = StarGaussianVectorDiffeomorphism(2, dist)

# %%
# test forward and inverse
x = torch.tensor([[8.0, 0.0], [0.0, 8.0], [-5.0, 1.0], [-1.0, -5.0]])
y = radial_diffeo.forward(x)
x_recon = radial_diffeo.inverse(y)  
print("Original x:\n", x)
print("Transformed y:\n", y)
print("Reconstructed x:\n", x_recon)
# Out:
# Original x:
#  tensor([[ 8.,  0.],
#         [ 0.,  8.],
#         [-5.,  1.],
#         [-1., -5.]])
# Transformed y:
#  tensor([[ 2.2857,  0.0000],
#         [ 0.0000,  2.2857],
#         [-2.0258,  0.4052],
#         [-0.4052, -2.0258]])
# Reconstructed x:
#  tensor([[ 8.,  0.],
#         [ 0.,  8.],
#         [-5.,  1.],
#         [-1., -5.]])

# %%
# Construct pullback manifold from radial diffeomorphism
manifold = StandardPullbackVectorEuclidean(radial_diffeo)

# %%
# compute geodesics between all of the x points
geodesics = manifold.geodesic(x[None],x[None],torch.linspace(0,1,20))

# plot geodesics
plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
for i in range(geodesics.shape[1]):
    for j in range(i+1, geodesics.shape[1]):
        plt.plot(geodesics[0, i, j, :, 0].numpy(), geodesics[0, i, j, :, 1].numpy(), marker='.')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# compute logs between the western most point and the other points
logs = manifold.log(x[2][None,None], x[[0,1,3]][None])

# quiver plot of the log vectors
plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
for i in range(logs.shape[2]):
    plt.arrow(x[2,0].item(), x[2,1].item(), logs[0,0,i,0].item(), logs[0,0,i,1].item(), head_width=0.3, head_length=0.3)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# compute exps of the log vectors to see whether we get the same points back
recon_points = manifold.exp(x[2][None], logs[0])

print("Original points:\n", x[[0,1,3]])
print("Reconstructed points from exp(log):\n", recon_points)
# Out:
# Original points:
#  tensor([[ 8.,  0.],
#         [ 0.,  8.],
#         [-1., -5.]])
# Reconstructed points from exp(log):
#  tensor([[[ 8.0000e+00,  9.3877e-07],
#          [-4.1723e-06,  8.0000e+00],
#          [-1.0000e+00, -5.0000e+00]]])

# %%
# geodesics from the origin now
origin = torch.tensor([[0.0, 0.0]])
geodesics_from_origin = manifold.geodesic(origin[None], x[None], torch.linspace(0,1,20))

# plot geodesics from origin
plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
for i in range(geodesics_from_origin.shape[2]):
    plt.plot(geodesics_from_origin[0, 0, i, :, 0].numpy(), geodesics_from_origin[0, 0, i, :, 1].numpy(), marker='.')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# logs from origin to the other points
logs_from_origin = manifold.log(origin[None], x[None])
print("Logs from origin to other points:\n", logs_from_origin)

# quiver plot of the log vectors from origin
plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
for i in range(logs_from_origin.shape[2]):
    plt.arrow(origin[0,0].item(), origin[0,1].item(), logs_from_origin[0,0,i,0].item(), logs_from_origin[0,0,i,1].item(), head_width=0.3, head_length=0.3)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Logs from origin to other points:
#  tensor([[[[ 2.2857,  0.0000],
#           [ 0.0000,  2.2857],
#           [-2.0258,  0.4052],
#           [-0.4052, -2.0258]]]])

# %%
# compute the exps of the log vectors from origin to see whether we get the same points back
recon_points_from_origin = manifold.exp(origin, logs_from_origin[0])
print("Original points:\n", x)
print("Reconstructed points from exp(log) from origin:\n", recon_points_from_origin)
# Out:
# Original points:
#  tensor([[ 8.,  0.],
#         [ 0.,  8.],
#         [-5.,  1.],
#         [-1., -5.]])
# Reconstructed points from exp(log) from origin:
#  tensor([[[ 8.,  0.],
#          [ 0.,  8.],
#          [-5.,  1.],
#          [-1., -5.]]])

# %% [markdown]
# ### Train model ###

# %%
# See if we can reconstruct the multimodal distribution from data
star_gaussian_dist = MultiInversePreBiasLinearStarGaussianDistribution(d=2, num_radials=2, centered=True)

# %%
# plot density
init_log_probs = torch.exp(star_gaussian_dist.log_prob(XY).reshape(n_points, n_points).detach())

plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), init_log_probs.numpy(), levels=10, cmap='viridis')
plt.colorbar(label='Density')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# create data set and loader from samples of the GT distribution to learn the multimodal distribution through NF training
from torch.utils.data import TensorDataset, DataLoader

data_set = TensorDataset(samples)
data_loader = DataLoader(data_set, batch_size=128, shuffle=True)

# %%
# training loop
num_epochs = 500
optimizer = torch.optim.Adam(star_gaussian_dist.parameters(), lr=1e-3)

for epoch in range(num_epochs):
    for batch in data_loader:
        # get batch of data
        batch_samples = batch[0]
        
        # compute log probs under the current model
        log_probs = star_gaussian_dist.log_prob(batch_samples)
        
        # compute loss (negative log likelihood)
        loss = -log_probs.mean()
        
        # backprop and update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}')
# Out:
# Epoch 1/500, Loss: 5.595413684844971
# Epoch 2/500, Loss: 5.435291290283203
# Epoch 3/500, Loss: 5.251093864440918
# Epoch 4/500, Loss: 5.083980083465576
# Epoch 5/500, Loss: 5.051876544952393
# Epoch 6/500, Loss: 5.051912307739258
# Epoch 7/500, Loss: 5.059634208679199
# Epoch 8/500, Loss: 4.928184509277344
# Epoch 9/500, Loss: 4.875475883483887
# Epoch 10/500, Loss: 4.8637590408325195
# Epoch 11/500, Loss: 4.721553325653076
# Epoch 12/500, Loss: 4.859149932861328
# Epoch 13/500, Loss: 4.804691314697266
# Epoch 14/500, Loss: 4.70341682434082
# Epoch 15/500, Loss: 4.52922248840332
# Epoch 16/500, Loss: 4.656123638153076
# Epoch 17/500, Loss: 4.543262481689453
# Epoch 18/500, Loss: 4.638501167297363
# Epoch 19/500, Loss: 4.645336627960205
# Epoch 20/500, Loss: 4.649618625640869
# Epoch 21/500, Loss: 4.617449760437012
# Epoch 22/500, Loss: 4.6635355949401855
# Epoch 23/500, Loss: 4.5893731117248535
# Epoch 24/500, Loss: 4.487735748291016
# Epoch 25/500, Loss: 4.491198539733887
# Epoch 26/500, Loss: 4.618531227111816
# Epoch 27/500, Loss: 4.475640773773193
# Epoch 28/500, Loss: 4.538837432861328
# Epoch 29/500, Loss: 4.442814350128174
# Epoch 30/500, Loss: 4.463249206542969
# Epoch 31/500, Loss: 4.4008049964904785
# Epoch 32/500, Loss: 4.475217342376709
# Epoch 33/500, Loss: 4.608814716339111
# Epoch 34/500, Loss: 4.4797821044921875
# Epoch 35/500, Loss: 4.5466532707214355
# Epoch 36/500, Loss: 4.433722972869873
# Epoch 37/500, Loss: 4.42534875869751
# Epoch 38/500, Loss: 4.308679580688477
# Epoch 39/500, Loss: 4.619030952453613
# Epoch 40/500, Loss: 4.596431732177734
# Epoch 41/500, Loss: 4.540613651275635
# Epoch 42/500, Loss: 4.535569190979004
# Epoch 43/500, Loss: 4.505157947540283
# Epoch 44/500, Loss: 4.367079257965088
# Epoch 45/500, Loss: 4.342657566070557
# Epoch 46/500, Loss: 4.452626705169678
# Epoch 47/500, Loss: 4.5620436668396
# Epoch 48/500, Loss: 4.350518703460693
# Epoch 49/500, Loss: 4.360850811004639
# Epoch 50/500, Loss: 4.322458744049072
# Epoch 51/500, Loss: 4.272893905639648
# Epoch 462/500, Loss: 4.221319198608398
# Epoch 463/500, Loss: 4.69942569732666
# Epoch 464/500, Loss: 4.422365188598633
# Epoch 465/500, Loss: 4.349442481994629
# Epoch 466/500, Loss: 4.498613357543945
# Epoch 467/500, Loss: 4.469512462615967
# Epoch 468/500, Loss: 4.471108436584473
# Epoch 469/500, Loss: 4.612537384033203
# Epoch 470/500, Loss: 4.381561279296875
# Epoch 471/500, Loss: 4.2950119972229
# Epoch 472/500, Loss: 4.2227325439453125
# Epoch 473/500, Loss: 4.393800735473633
# Epoch 474/500, Loss: 4.311722755432129
# Epoch 475/500, Loss: 4.198246479034424
# Epoch 476/500, Loss: 4.384898662567139
# Epoch 477/500, Loss: 4.5148797035217285
# Epoch 478/500, Loss: 4.392688751220703
# Epoch 479/500, Loss: 4.3310418128967285
# Epoch 480/500, Loss: 4.2319769859313965
# Epoch 481/500, Loss: 4.328434467315674
# Epoch 482/500, Loss: 4.338328838348389
# Epoch 483/500, Loss: 4.467138290405273
# Epoch 484/500, Loss: 4.370361328125
# Epoch 485/500, Loss: 4.465619087219238
# Epoch 486/500, Loss: 4.213284492492676
# Epoch 487/500, Loss: 4.360867500305176
# Epoch 488/500, Loss: 4.291955471038818
# Epoch 489/500, Loss: 4.3899054527282715
# Epoch 490/500, Loss: 4.211341381072998
# Epoch 491/500, Loss: 4.351912498474121
# Epoch 492/500, Loss: 4.5143656730651855
# Epoch 493/500, Loss: 4.425483226776123
# Epoch 494/500, Loss: 4.297634124755859
# Epoch 495/500, Loss: 4.414397716522217
# Epoch 496/500, Loss: 4.4646124839782715
# Epoch 497/500, Loss: 4.194306373596191
# Epoch 498/500, Loss: 4.303022861480713
# Epoch 499/500, Loss: 4.274289608001709
# Epoch 500/500, Loss: 4.479414939880371

# %%
# plot trained density
trained_log_probs = torch.exp(star_gaussian_dist.log_prob(XY).reshape(n_points, n_points).detach())

plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), trained_log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
plt.scatter(samples[:,0], samples[:,1], marker='.', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# extract mode variances to see if we can identify the two modes
print("Mode variances:\n", star_gaussian_dist.radial.mode_variance(0).round(decimals=2), "\n", star_gaussian_dist.radial.mode_variance(1).round(decimals=2))
# Out:
# Mode variances:
#  tensor([[0.3400, 0.0000],
#         [0.0000, 5.8800]])
#  tensor([[ 6.4800, -0.1000],
#         [-0.1000,  0.2900]])

# %%
mode_0 = star_gaussian_dist.extract_mode(0)
mode_1 = star_gaussian_dist.extract_mode(1)

# sample from the extracted modes to see if they correspond to the two modes of the distribution
mode_0_samples = mode_0.sample(1000).detach()
mode_1_samples = mode_1.sample(1000).detach()

plt.figure(figsize=(6,6))
plt.contour(X.numpy(), Y.numpy(), trained_log_probs.numpy(), levels=10, cmap='viridis', alpha=0.5)
plt.scatter(mode_0_samples[:,0], mode_0_samples[:,1], marker='.', label='Mode 0 Samples')
plt.scatter(mode_1_samples[:,0], mode_1_samples[:,1], marker='.', label='Mode 1 Samples')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.tight_layout()
plt.show()
